# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
#read the CSV
df_game_data = pd.read_csv("game_database_final.csv")
df_game_data.head()
# Out:
#        Game     Month Hours Watched Hours Gained % Hour Gained  \
# 0  Among Us  01/01/21         27.1M       -23.2M       -46.10%
# 1  Among Us  12/01/20         50.3M       -26.7M       -34.70%
# 2  Among Us  11/01/20         77.0M       -32.6M       -29.70%
# 3  Among Us  10/01/20         83.4M       -63.5M       -43.20%
# 4  Among Us  09/01/20          147M        +116M          380%
#
#   Average Viewers  Viewers Gained % Viewers Gained Peak Concurrent Viewers   \
# 0           42.0K         -25,759             -38%                     269K
# 1           67.7K         -39,400          -36.80%                     499K
# 2            107K         -40,281          -27.30%                     774K
# 3            3.0K            -450          -12.90%                     9.1K
# 4            3.5K           2,985             598%                    12.4K
#
#   Average Concurrent Streams Concurrent Streams Gain  \
# 0                        895                    -312
# ...
