# %%
# import dependencies
import pandas as pd
import pymongo

# %%
# define csv to import
csv = 'game_database_final.csv'

# %%
# read csv and preview
df = pd.read_csv(csv)
df
# Out:
#                    Game    Month Hours Watched Average Viewers  \
# 0              Among Us   1/1/21         27.1M           42.0K
# 1              Among Us  12/1/20         50.3M           67.7K
# 2              Among Us  11/1/20         77.0M            107K
# 3              Among Us  10/1/20         83.4M            3.0K
# 4              Among Us   9/1/20          147M            3.5K
# ..                  ...      ...           ...             ...
# 186  League of Legends    4/1/17         82.5M            115K
# 187  League of Legends    3/1/17         90.8M            122K
# 188  League of Legends    2/1/17         99.3M            148K
# 189  League of Legends    1/1/17         99.1M            134K
# 190  League of Legends   12/1/16         81.0M            109K
#
#     Average Concurrent Streams Peak Concurrent Streams Peak Viewers
# 0                          895                    2.4K          269K
# 1                         1.2K                    3.3K          499K
# 2                         1.8K                    5.3K          774K
# 3                         151K                    754K          9.1K
# 4                         204K                    743K         12.4K
# ..                         ...                     ...           ...
# 186                       1.6K                    2.5K          488K
# 187                       1.6K                    2.5K          326K
# 188                       1.8K                    2.8K          391K
# 189                       1.8K                    2.9K          378K
# 190                       1.7K                    2.5K          334K
#
# [191 rows x 7 columns]

# %%
# rename columns
columns = ['game', 'month', 'hours_watched', 'average_viewers(k)', 'average_concurrent_streams(k)', 'peak_concurrent_streams(k)', 'peak_viewers(k)']
df.columns = columns
df
# Out:
#                    game    month hours_watched average_viewers(k)  \
# 0              Among Us   1/1/21         27.1M              42.0K
# 1              Among Us  12/1/20         50.3M              67.7K
# 2              Among Us  11/1/20         77.0M               107K
# 3              Among Us  10/1/20         83.4M               3.0K
# 4              Among Us   9/1/20          147M               3.5K
# ..                  ...      ...           ...                ...
# 186  League of Legends    4/1/17         82.5M               115K
# 187  League of Legends    3/1/17         90.8M               122K
# 188  League of Legends    2/1/17         99.3M               148K
# 189  League of Legends    1/1/17         99.1M               134K
# 190  League of Legends   12/1/16         81.0M               109K
#
#     average_concurrent_streams(k) peak_concurrent_streams(k) peak_viewers(k)
# 0                             895                       2.4K            269K
# 1                            1.2K                       3.3K            499K
# 2                            1.8K                       5.3K            774K
# 3                            151K                       754K            9.1K
# 4                            204K                       743K           12.4K
# ..                            ...                        ...             ...
# 186                          1.6K                       2.5K            488K
# 187                          1.6K                       2.5K            326K
# 188                          1.8K                       2.8K            391K
# 189                          1.8K                       2.9K            378K
# 190                          1.7K                       2.5K            334K
#
# [191 rows x 7 columns]

# %%
# format columns
df['month'] = pd.to_datetime(df['month'], format='%d/%m/%y')
df['hours_watched'] = df['hours_watched'].map(lambda x: float(x.strip('M')) if 'M' in x else float(x.strip('K'))/1000000)
df['average_viewers(k)'] = df['average_viewers(k)'].map(lambda x: float(x.strip('K')))
df['average_concurrent_streams(k)'] = df['average_concurrent_streams(k)'].map(lambda x: float(x.strip('K')) if 'K' in x else float(x)/1000)
df['peak_concurrent_streams(k)'] = df['peak_concurrent_streams(k)'].map(lambda x: float(x.strip('K')) if 'K' in x else float(x)/1000)
df['peak_viewers(k)'] = df['peak_viewers(k)'].map(lambda x: float(x.strip('K')) if 'K' in x else float(x.strip('M'))*1000)
df
# Out:
#                    game      month  hours_watched  average_viewers(k)  \
# 0              Among Us 2021-01-01           27.1                42.0
# 1              Among Us 2020-01-12           50.3                67.7
# 2              Among Us 2020-01-11           77.0               107.0
# 3              Among Us 2020-01-10           83.4                 3.0
# 4              Among Us 2020-01-09          147.0                 3.5
# ..                  ...        ...            ...                 ...
# 186  League of Legends  2017-01-04           82.5               115.0
# 187  League of Legends  2017-01-03           90.8               122.0
# 188  League of Legends  2017-01-02           99.3               148.0
# 189  League of Legends  2017-01-01           99.1               134.0
# 190  League of Legends  2016-01-12           81.0               109.0
#
#      average_concurrent_streams(k)  peak_concurrent_streams(k)  \
# 0                            0.895                         2.4
# 1                            1.200                         3.3
# 2                            1.800                         5.3
# 3                          151.000                       754.0
# 4                          204.000                       743.0
# ..                             ...                         ...
# 186                          1.600                         2.5
# 187                          1.600                         2.5
# 188                          1.800                         2.8
# 189                          1.800                         2.9
# 190                          1.700                         2.5
#
#      peak_viewers(k)
# 0              269.0
# 1              499.0
# 2              774.0
# 3                9.1
# 4               12.4
# ..               ...
# 186            488.0
# 187            326.0
# 188            391.0
# 189            378.0
# 190            334.0
#
# [191 rows x 7 columns]

# %%
# check names for unique games in dataframe
df['game'].unique()
# Out:
# array(['Among Us', 'Call of Duty ', 'Counter Strike Global Offensive',
#        'Fortnite', 'League of Legends '], dtype=object)

# %%
# split data for each game into separate dataframes
amongus_df = df.loc[df['game'] == 'Among Us']
cod_df = df.loc[df['game'] == 'Call of Duty ']
csgo_df = df.loc[df['game'] == 'Counter Strike Global Offensive']
fortnite_df = df.loc[df['game'] == 'Fortnite']
lol_df = df.loc[df['game'] == 'League of Legends ']

# %%
# reset index and set month as index
df_list = [amongus_df, cod_df, csgo_df, fortnite_df, lol_df]
for x in df_list:
    x.reset_index(drop=True, inplace=True)
    x.set_index('month', inplace=True)

# %%
# preview df sample
lol_df
# Out:
#                           game  hours_watched  average_viewers(k)  \
# month
# 2021-01-01  League of Legends           145.0               224.0
# 2020-01-12  League of Legends            96.2               130.0
# 2020-01-11  League of Legends           121.0               168.0
# 2020-01-10  League of Legends           125.0               226.0
# 2020-01-09  League of Legends           135.0               187.0
# 2020-01-08  League of Legends           142.0               192.0
# 2020-01-07  League of Legends           135.0               182.0
# 2020-01-06  League of Legends           143.0               199.0
# 2020-01-05  League of Legends           127.0               172.0
# 2020-01-04  League of Legends           135.0               189.0
# 2020-01-03  League of Legends           123.0               166.0
# 2020-01-02  League of Legends           121.0               175.0
# 2020-01-01  League of Legends            99.7               134.0
# 2019-01-12  League of Legends            78.5               106.0
# 2019-01-11  League of Legends            91.8               132.0
# 2019-01-10  League of Legends           121.0               170.0
# 2019-01-09  League of Legends            77.6               108.0
# 2019-01-08  League of Legends            86.1               116.0
# 2019-01-07  League of Legends            68.2                91.7
# 2019-01-06  League of Legends            89.1               124.0
# 2019-01-05  League of Legends           103.0               138.0
# 2019-01-04  League of Legends            92.4               128.0
# 2019-01-03  League of Legends           108.0               146.0
# 2019-01-02  League of Legends            95.0               141.0
# 2019-01-01  League of Legends            99.1               133.0
# 2018-01-12  League of Legends            72.0                96.8
# 2018-01-11  League of Legends            84.5               117.0
# 2018-01-10  League of Legends           109.0               147.0
# 2018-01-09  League of Legends            76.5               106.0
# 2018-01-08  League of Legends            81.2               109.0
# 2018-01-07  League of Legends            74.9               102.0
# 2018-01-06  League of Legends            72.4               101.0
# 2018-01-05  League of Legends            82.0               110.0
# 2018-01-04  League of Legends            74.1               103.0
# 2018-01-03  League of Legends            88.8               119.0
# 2018-01-02  League of Legends            81.0               121.0
# 2018-01-01  League of Legends            89.0               120.0
# 2017-01-12  League of Legends            69.6                93.5
# 2017-01-11  League of Legends            82.8               115.0
# 2017-01-10  League of Legends            94.6               127.0
# 2017-01-09  League of Legends            74.4               103.0
# 2017-01-08  League of Legends            71.8                96.7
# 2017-01-07  League of Legends            84.6               114.0
# 2017-01-06  League of Legends            84.6               118.0
# 2017-01-05  League of Legends            86.6               118.0
# 2017-01-04  League of Legends            82.5               115.0
# 2017-01-03  League of Legends            90.8               122.0
# 2017-01-02  League of Legends            99.3               148.0
# 2017-01-01  League of Legends            99.1               134.0
# 2016-01-12  League of Legends            81.0               109.0
#
#             average_concurrent_streams(k)  peak_concurrent_streams(k)  \
# month
# 2021-01-01                            5.8                        11.6
# 2020-01-12                            4.4                         8.0
# 2020-01-11                            4.7                         8.9
# 2020-01-10                            4.5                         8.5
# 2020-01-09                            4.4                         6.8
# 2020-01-08                            4.4                         7.5
# 2020-01-07                            4.4                         7.3
# 2020-01-06                            4.2                         7.5
# 2020-01-05                            4.7                         8.3
# 2020-01-04                            4.8                         8.8
# 2020-01-03                            4.1                         8.4
# 2020-01-02                            3.7                         7.3
# 2020-01-01                            4.0                         8.0
# 2019-01-12                            3.1                         6.4
# 2019-01-11                            3.0                         4.5
# 2019-01-10                            3.0                         5.9
# 2019-01-09                            2.7                         4.5
# 2019-01-08                            2.7                         5.3
# 2019-01-07                            2.4                         3.4
# 2019-01-06                            2.8                         3.9
# 2019-01-05                            2.8                         4.1
# 2019-01-04                            2.7                         4.0
# 2019-01-03                            2.6                         4.0
# 2019-01-02                            2.6                         4.5
# 2019-01-01                            3.0                         6.1
# 2018-01-12                            2.4                         3.5
# 2018-01-11                            2.4                         5.0
# 2018-01-10                            2.2                         3.4
# 2018-01-09                            2.1                         3.1
# 2018-01-08                            2.0                         2.8
# 2018-01-07                            1.8                         2.8
# 2018-01-06                            1.8                         3.3
# 2018-01-05                            1.9                         2.8
# 2018-01-04                            2.0                         3.9
# 2018-01-03                            2.1                         3.2
# 2018-01-02                            2.3                         3.5
# 2018-01-01                            2.4                         4.8
# 2017-01-12                            1.9                         3.2
# 2017-01-11                            1.9                         2.9
# 2017-01-10                            1.8                         2.8
# 2017-01-09                            1.7                         2.6
# 2017-01-08                            1.7                         2.7
# 2017-01-07                            1.7                         2.5
# 2017-01-06                            1.6                         2.4
# 2017-01-05                            1.7                         2.5
# 2017-01-04                            1.6                         2.5
# 2017-01-03                            1.6                         2.5
# 2017-01-02                            1.8                         2.8
# 2017-01-01                            1.8                         2.9
# 2016-01-12                            1.7                         2.5
#
#             peak_viewers(k)
# month
# 2021-01-01            699.0
# 2020-01-12            320.0
# 2020-01-11            345.0
# 2020-01-10           1420.0
# 2020-01-09            795.0
# 2020-01-08            730.0
# 2020-01-07            505.0
# 2020-01-06            561.0
# 2020-01-05            507.0
# 2020-01-04            736.0
# 2020-01-03            430.0
# 2020-01-02            402.0
# 2020-01-01            348.0
# 2019-01-12            232.0
# 2019-01-11           1740.0
# 2019-01-10           1100.0
# 2019-01-09            654.0
# 2019-01-08            463.0
# 2019-01-07            275.0
# 2019-01-06            322.0
# 2019-01-05            816.0
# 2019-01-04            548.0
# 2019-01-03            377.0
# 2019-01-02            370.0
# 2019-01-01            400.0
# 2018-01-12            344.0
# 2018-01-11           1130.0
# 2018-01-10            923.0
# 2018-01-09            424.0
# 2018-01-08            934.0
# 2018-01-07            232.0
# 2018-01-06            244.0
# 2018-01-05            511.0
# 2018-01-04            486.0
# 2018-01-03            364.0
# 2018-01-02            305.0
# 2018-01-01            440.0
# 2017-01-12            325.0
# 2017-01-11           1090.0
# 2017-01-10            886.0
# 2017-01-09            376.0
# 2017-01-08            350.0
# 2017-01-07            326.0
# 2017-01-06            281.0
# 2017-01-05            648.0
# 2017-01-04            488.0
# 2017-01-03            326.0
# 2017-01-02            391.0
# 2017-01-01            378.0
# 2016-01-12            334.0

# %%
def setup_game_db():
    
    # define csv to import
    csv = 'game_database_final.csv'
    
    # read csv and preview
    df = pd.read_csv(csv)
    
    # rename columns
    columns = ['game', 'month', 'hours_watched', 'average_viewers(k)', 'average_concurrent_streams(k)', 'peak_concurrent_streams(k)', 'peak_viewers(k)']
    df.columns = columns
    
    # format columns
#     df['month'] = pd.to_datetime(df['month'], format='%d/%m/%y')
    df['hours_watched'] = df['hours_watched'].map(lambda x: float(x.strip('M')) if 'M' in x else float(x.strip('K'))/1000000)
    df['average_viewers(k)'] = df['average_viewers(k)'].map(lambda x: float(x.strip('K')))
    df['average_concurrent_streams(k)'] = df['average_concurrent_streams(k)'].map(lambda x: float(x.strip('K')) if 'K' in x else float(x)/1000)
    df['peak_concurrent_streams(k)'] = df['peak_concurrent_streams(k)'].map(lambda x: float(x.strip('K')) if 'K' in x else float(x)/1000)
    df['peak_viewers(k)'] = df['peak_viewers(k)'].map(lambda x: float(x.strip('K')) if 'K' in x else float(x.strip('M'))*1000)

    # split data for each game into separate dataframes
    amongus_df = df.loc[df['game'] == 'Among Us']
    cod_df = df.loc[df['game'] == 'Call of Duty ']
    csgo_df = df.loc[df['game'] == 'Counter Strike Global Offensive']
    fortnite_df = df.loc[df['game'] == 'Fortnite']
    lol_df = df.loc[df['game'] == 'League of Legends ']
    
    # reset index and set month as index
    df_list = [amongus_df, cod_df, csgo_df, fortnite_df, lol_df]
    for x in df_list:
        x.reset_index(drop=True, inplace=True)
        x.set_index('month', inplace=True)
        
    return df_list

# %%
def df_rows_todict(dataframe):
    df_dict = {}
    for index, row in dataframe.iterrows():
        column_values = row.to_dict()
        df_dict[index] = column_values
    return df_dict

# %%
def upload_db(collection, dictionary):
    db_name = 'project2'
    myclient = pymongo.MongoClient('mongodb://localhost:27017/')
    mydb = myclient[db_name]
    mycol = mydb[collection]
    # error handling in case collection already exists in database
    try:
        upload = mycol.insert_one(dictionary)
    except:
        print('This collection already exists. Change collection name or delete collection in mongodb before trying again.')

# %%
df_list = setup_game_db()

# %%
db_names = ['amongus_db', 'cod_db', 'csgo_db', 'fortnite_db', 'lol_db']
for index, value in enumerate(df_list):
    collection = db_names[index]
    df = df_list[index]
    dictionary = df_rows_todict(df)
    upload_db(collection, dictionary)
